# %% [markdown]
# # Analysis and Visualization of Complex Agro-Environmental Data
# ---
# ### Exercise #8 - correction

# %%
import pandas as pd
import zipfile
import seaborn as sns # For plotting
import matplotlib.pyplot as plt # For showing plots
import numpy as np # for getting our distribution
import seaborn as sns # for plotting
from scipy import stats # to compute statistics
import statsmodels.api as sm

# %%
df = pd.read_csv('../exemplos/EFIplus_medit.zip',compression='zip', sep=";")
df = df.dropna() # remove all rows with missing data

# %% [markdown]
# #### 8.1. Run a simple linear regression relating the species richness with each one of the continuous environmental variables in the dataset: Altitude, Actual_river_slope, Elevation_mean_catch, prec_ann_catch, temp_ann, temp_jan, temp_jul. Before running the analyses, check if any of the variables requires to be transformed and apply the appropriate transformation. Compute the regression coefficient estimates, the r-square and the F-statistics. You may plot the fitted model.

# %% [markdown]
# 1. create columns with species richness (from previous exercise)

# %%
# check the name of the first column of species names in the names list:
list(df)

# %%
# Now check the index of the first species column
df.columns.get_loc("Abramis brama")
# Out:
# 56

# %%
# The species columns goes from 56 to the last column - extract the name of the spceis columns
sp_pres = df.columns[56:]
sp_pres

# sum all the species presence/absence data into a new column named 'sp_rich'
df['sp_rich'] = df[sp_pres].sum(axis=1)

# %% [markdown]
# 2. subset df and transform data (from previous exercise)

# %%
# Subset the df by selecting the environmental variables and the species richness columns
df_rich_env = df[["sp_rich", "Altitude", "Actual_river_slope","Elevation_mean_catch", "prec_ann_catch","temp_ann","temp_jan","temp_jul"]]
df_rich_env

# Better to transform "Actual_river_slope" (e.g. log(x+1) - need to add 1 because there are 0's) - RUN IT ONLY ONCE!!!
df_rich_env[['Actual_river_slope']] = np.log10(df_rich_env[['Actual_river_slope']]+1)
sns.histplot(data=df_rich_env[["Actual_river_slope"]])
# Out:
# C:\Users\psegurado\AppData\Local\Temp\ipykernel_18652\1207881086.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rich_env[['Actual_river_slope']] = np.log10(df_rich_env[['Actual_river_slope']]+1)
# <Axes: ylabel='Count'>

# %% [markdown]
# 3. Run regressions

# %%
# Run regression for each environmental variable. import formula api as alias smf 
import statsmodels.formula.api as smf

# formula: response ~ predictor
model_alt = smf.ols(formula='sp_rich ~ Altitude', data=df_rich_env).fit().summary()
model_slope = smf.ols(formula='sp_rich ~ Actual_river_slope', data=df_rich_env).fit().summary()
model_elev = smf.ols(formula='sp_rich ~ Elevation_mean_catch', data=df_rich_env).fit().summary()
model_prec = smf.ols(formula='sp_rich ~ prec_ann_catch', data=df_rich_env).fit().summary()
model_temp = smf.ols(formula='sp_rich ~ temp_ann', data=df_rich_env).fit().summary()
model_tempjan = smf.ols(formula='sp_rich ~ temp_jan', data=df_rich_env).fit().summary()
model_tempjul = smf.ols(formula='sp_rich ~ temp_jul', data=df_rich_env).fit().summary()

print(model_alt)
print(model_slope)
print(model_elev)
print(model_prec)
print(model_temp)
print(model_tempjan)
print(model_tempjul)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sp_rich   R-squared:                       0.166
# Model:                            OLS   Adj. R-squared:                  0.166
# Method:                 Least Squares   F-statistic:                     562.7
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):          1.45e-113
# Time:                        10:27:58   Log-Likelihood:                -6256.1
# No. Observations:                2822   AIC:                         1.252e+04
# Df Residuals:                    2820   BIC:                         1.253e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.5929      0.065     70.854      0.000       4.466       4.720
# Altitude      -0.0034      0.000    -23.721      0.000      -0.004      -0.003
# ==============================================================================
# Omnibus:                      393.043   Durbin-Watson:                   0.870
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              588.199
# Skew:                           1.003   Prob(JB):                    1.88e-128
# Kurtosis:                       3.990   Cond. No.                         699.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sp_rich   R-squared:                       0.192
# Model:                            OLS   Adj. R-squared:                  0.192
# Method:                 Least Squares   F-statistic:                     669.6
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):          1.17e-132
# Time:                        10:27:58   Log-Likelihood:                -6212.2
# No. Observations:                2822   AIC:                         1.243e+04
# Df Residuals:                    2820   BIC:                         1.244e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              5.7990      0.101     57.529      0.000       5.601       5.997
# Actual_river_slope    -2.4097      0.093    -25.877      0.000      -2.592      -2.227
# ==============================================================================
# Omnibus:                      315.315   Durbin-Watson:                   0.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              450.051
# Skew:                           0.850   Prob(JB):                     1.87e-98
# Kurtosis:                       3.967   Cond. No.                         4.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sp_rich   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.091
# Method:                 Least Squares   F-statistic:                     282.1
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):           2.03e-60
# Time:                        10:27:58   Log-Likelihood:                -6378.3
# No. Observations:                2822   AIC:                         1.276e+04
# Df Residuals:                    2820   BIC:                         1.277e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                4.7398      0.090     52.667      0.000       4.563       4.916
# Elevation_mean_catch    -0.0020      0.000    -16.797      0.000      -0.002      -0.002
# ==============================================================================
# Omnibus:                      356.156   Durbin-Watson:                   0.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              504.331
# Skew:                           0.968   Prob(JB):                    3.06e-110
# Kurtosis:                       3.738   Cond. No.                     1.58e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sp_rich   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.070
# Method:                 Least Squares   F-statistic:                     212.7
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):           1.66e-46
# Time:                        10:27:58   Log-Likelihood:                -6410.2
# No. Observations:                2822   AIC:                         1.282e+04
# Df Residuals:                    2820   BIC:                         1.284e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          6.1667      0.194     31.859      0.000       5.787       6.546
# prec_ann_catch    -0.0026      0.000    -14.585      0.000      -0.003      -0.002
# ==============================================================================
# Omnibus:                      269.506   Durbin-Watson:                   0.848
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              349.621
# Skew:                           0.850   Prob(JB):                     1.20e-76
# Kurtosis:                       3.291   Cond. No.                     4.82e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.82e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sp_rich   R-squared:                       0.283
# Model:                            OLS   Adj. R-squared:                  0.282
# Method:                 Least Squares   F-statistic:                     1111.
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):          1.28e-205
# Time:                        10:27:58   Log-Likelihood:                -6044.3
# No. Observations:                2822   AIC:                         1.209e+04
# Df Residuals:                    2820   BIC:                         1.210e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.6824      0.276    -20.602      0.000      -6.223      -5.142
# temp_ann       0.6775      0.020     33.326      0.000       0.638       0.717
# ==============================================================================
# Omnibus:                      342.423   Durbin-Watson:                   1.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              533.746
# Skew:                           0.859   Prob(JB):                    1.25e-116
# Kurtosis:                       4.261   Cond. No.                         97.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sp_rich   R-squared:                       0.127
# Model:                            OLS   Adj. R-squared:                  0.127
# Method:                 Least Squares   F-statistic:                     410.5
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):           2.55e-85
# Time:                        10:27:58   Log-Likelihood:                -6321.1
# No. Observations:                2822   AIC:                         1.265e+04
# Df Residuals:                    2820   BIC:                         1.266e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9156      0.131      7.004      0.000       0.659       1.172
# temp_jan       0.3553      0.018     20.261      0.000       0.321       0.390
# ==============================================================================
# Omnibus:                      406.119   Durbin-Watson:                   0.857
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              622.343
# Skew:                           1.014   Prob(JB):                    7.24e-136
# Kurtosis:                       4.088   Cond. No.                         23.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sp_rich   R-squared:                       0.334
# Model:                            OLS   Adj. R-squared:                  0.333
# Method:                 Least Squares   F-statistic:                     1412.
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):          6.32e-251
# Time:                        10:27:58   Log-Likelihood:                -5940.0
# No. Observations:                2822   AIC:                         1.188e+04
# Df Residuals:                    2820   BIC:                         1.190e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -10.4399      0.371    -28.166      0.000     -11.167      -9.713
# temp_jul       0.6957      0.019     37.580      0.000       0.659       0.732
# ==============================================================================
# Omnibus:                      220.214   Durbin-Watson:                   1.141
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              322.482
# Skew:                           0.626   Prob(JB):                     9.42e-71
# Kurtosis:                       4.084   Cond. No.                         199.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sns.lmplot(x='Altitude', y='sp_rich', data=df_rich_env)
sns.lmplot(x='Actual_river_slope', y='sp_rich', data=df_rich_env)
sns.lmplot(x='Elevation_mean_catch', y='sp_rich', data=df_rich_env)
sns.lmplot(x='prec_ann_catch', y='sp_rich', data=df_rich_env)
sns.lmplot(x='temp_ann', y='sp_rich', data=df_rich_env)
sns.lmplot(x='temp_jan', y='sp_rich', data=df_rich_env)

# %%
# Alternative using a loop

import statsmodels.api as sm

explan_vars = ["Altitude", "Actual_river_slope","Elevation_mean_catch", "prec_ann_catch","temp_ann","temp_jan","temp_jul"]

# Loop
for Xi in explan_vars: # loop for each variable name
    # Extract the response and explanatory variables
    y = df_rich_env['sp_rich']
    X = df_rich_env[Xi]
    
    # Add a constant term to the explanatory variable (intercept term)
    X = sm.add_constant(X)
    
    # Fit the linear regression model
    model = sm.OLS(y, X)
    results = model.fit()
    
    # Print the results
    print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sp_rich   R-squared:                       0.166
# Model:                            OLS   Adj. R-squared:                  0.166
# Method:                 Least Squares   F-statistic:                     562.7
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):          1.45e-113
# Time:                        10:28:00   Log-Likelihood:                -6256.1
# No. Observations:                2822   AIC:                         1.252e+04
# Df Residuals:                    2820   BIC:                         1.253e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.5929      0.065     70.854      0.000       4.466       4.720
# Altitude      -0.0034      0.000    -23.721      0.000      -0.004      -0.003
# ==============================================================================
# Omnibus:                      393.043   Durbin-Watson:                   0.870
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              588.199
# Skew:                           1.003   Prob(JB):                    1.88e-128
# Kurtosis:                       3.990   Cond. No.                         699.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sp_rich   R-squared:                       0.192
# Model:                            OLS   Adj. R-squared:                  0.192
# Method:                 Least Squares   F-statistic:                     669.6
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):          1.17e-132
# Time:                        10:28:00   Log-Likelihood:                -6212.2
# No. Observations:                2822   AIC:                         1.243e+04
# Df Residuals:                    2820   BIC:                         1.244e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  5.7990      0.101     57.529      0.000       5.601       5.997
# Actual_river_slope    -2.4097      0.093    -25.877      0.000      -2.592      -2.227
# ==============================================================================
# Omnibus:                      315.315   Durbin-Watson:                   0.930
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              450.051
# Skew:                           0.850   Prob(JB):                     1.87e-98
# Kurtosis:                       3.967   Cond. No.                         4.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sp_rich   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.091
# Method:                 Least Squares   F-statistic:                     282.1
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):           2.03e-60
# Time:                        10:28:00   Log-Likelihood:                -6378.3
# No. Observations:                2822   AIC:                         1.276e+04
# Df Residuals:                    2820   BIC:                         1.277e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    4.7398      0.090     52.667      0.000       4.563       4.916
# Elevation_mean_catch    -0.0020      0.000    -16.797      0.000      -0.002      -0.002
# ==============================================================================
# Omnibus:                      356.156   Durbin-Watson:                   0.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              504.331
# Skew:                           0.968   Prob(JB):                    3.06e-110
# Kurtosis:                       3.738   Cond. No.                     1.58e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.58e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sp_rich   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.070
# Method:                 Least Squares   F-statistic:                     212.7
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):           1.66e-46
# Time:                        10:28:00   Log-Likelihood:                -6410.2
# No. Observations:                2822   AIC:                         1.282e+04
# Df Residuals:                    2820   BIC:                         1.284e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              6.1667      0.194     31.859      0.000       5.787       6.546
# prec_ann_catch    -0.0026      0.000    -14.585      0.000      -0.003      -0.002
# ==============================================================================
# Omnibus:                      269.506   Durbin-Watson:                   0.848
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              349.621
# Skew:                           0.850   Prob(JB):                     1.20e-76
# Kurtosis:                       3.291   Cond. No.                     4.82e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.82e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sp_rich   R-squared:                       0.283
# Model:                            OLS   Adj. R-squared:                  0.282
# Method:                 Least Squares   F-statistic:                     1111.
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):          1.28e-205
# Time:                        10:28:00   Log-Likelihood:                -6044.3
# No. Observations:                2822   AIC:                         1.209e+04
# Df Residuals:                    2820   BIC:                         1.210e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -5.6824      0.276    -20.602      0.000      -6.223      -5.142
# temp_ann       0.6775      0.020     33.326      0.000       0.638       0.717
# ==============================================================================
# Omnibus:                      342.423   Durbin-Watson:                   1.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              533.746
# Skew:                           0.859   Prob(JB):                    1.25e-116
# Kurtosis:                       4.261   Cond. No.                         97.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sp_rich   R-squared:                       0.127
# Model:                            OLS   Adj. R-squared:                  0.127
# Method:                 Least Squares   F-statistic:                     410.5
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):           2.55e-85
# Time:                        10:28:00   Log-Likelihood:                -6321.1
# No. Observations:                2822   AIC:                         1.265e+04
# Df Residuals:                    2820   BIC:                         1.266e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9156      0.131      7.004      0.000       0.659       1.172
# temp_jan       0.3553      0.018     20.261      0.000       0.321       0.390
# ==============================================================================
# Omnibus:                      406.119   Durbin-Watson:                   0.857
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              622.343
# Skew:                           1.014   Prob(JB):                    7.24e-136
# Kurtosis:                       4.088   Cond. No.                         23.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sp_rich   R-squared:                       0.334
# Model:                            OLS   Adj. R-squared:                  0.333
# Method:                 Least Squares   F-statistic:                     1412.
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):          6.32e-251
# Time:                        10:28:00   Log-Likelihood:                -5940.0
# No. Observations:                2822   AIC:                         1.188e+04
# Df Residuals:                    2820   BIC:                         1.190e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -10.4399      0.371    -28.166      0.000     -11.167      -9.713
# temp_jul       0.6957      0.019     37.580      0.000       0.659       0.732
# ==============================================================================
# Omnibus:                      220.214   Durbin-Watson:                   1.141
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              322.482
# Skew:                           0.626   Prob(JB):                     9.42e-71
# Kurtosis:                       4.084   Cond. No.                         199.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### 8.2 Now try to run a multiple linear regression with the same data and check the differences between the previous univariate regression coefficients and the new coefficients. Plot the partial dependence plots to compare responses with the previous single effects.

# %%
# Multiple linear regression with the same data and check the differences between the previous univariate regression coefficients and new coefficients

y=df_rich_env["sp_rich"]
x=df_rich_env[["Altitude", "Actual_river_slope","Elevation_mean_catch", "prec_ann_catch","temp_ann","temp_jan","temp_jul"]]

x = sm.add_constant(x) # adding a constant (Intercept)

model = sm.OLS(y, x).fit()
predictions = model.predict(df_rich_env) 

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sp_rich   R-squared:                       0.407
# Model:                            OLS   Adj. R-squared:                  0.405
# Method:                 Least Squares   F-statistic:                     275.6
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):          2.17e-313
# Time:                        10:28:00   Log-Likelihood:                -5776.1
# No. Observations:                2822   AIC:                         1.157e+04
# Df Residuals:                    2814   BIC:                         1.162e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -5.0405      0.766     -6.576      0.000      -6.543      -3.538
# Altitude                -0.0028      0.000     -8.668      0.000      -0.003      -0.002
# Actual_river_slope      -1.1878      0.093    -12.750      0.000      -1.370      -1.005
# Elevation_mean_catch     0.0006      0.000      2.416      0.016       0.000       0.001
# prec_ann_catch           0.0003      0.000      1.657      0.098    -5.2e-05       0.001
# temp_ann                 0.2235      0.139      1.604      0.109      -0.050       0.497
# temp_jan                -0.2822      0.075     -3.741      0.000      -0.430      -0.134
# temp_jul                 0.4478      0.066      6.795      0.000       0.319       0.577
# ==============================================================================
# Omnibus:                      187.762   Durbin-Watson:                   1.203
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              297.790
# Skew:                           0.527   Prob(JB):                     2.17e-65
# Kurtosis:                       4.192   Cond. No.                     2.94e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.94e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Get partial dependency plots (compare with the univariate plots above)
fig = plt.figure(figsize=(8, 10))
sm.graphics.plot_partregress_grid(model, fig=fig)
fig.tight_layout(pad=1.0)
plt.show()
# Out:
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1

# %% [markdown]
# #### 8.3 Check the multicolinearity among the predictor variables and run a second more parsimonious regression model. Check how the coefficients have changed.

# %%
# Visualization of the correlation matrix

# Create plotting function
def corrdot(*args, **kwargs):
    corr_r = args[0].corr(args[1], 'pearson')
    corr_text = f"{corr_r:2.2f}".replace("0.", ".")
    ax = plt.gca()
    ax.set_axis_off()
    marker_size = abs(corr_r) * 10000
    ax.scatter([.5], [.5], marker_size, [corr_r], alpha=0.6, cmap="coolwarm",
               vmin=-1, vmax=1, transform=ax.transAxes)
    font_size = abs(corr_r) * 40 + 5
    ax.annotate(corr_text, [.5, .5,],  xycoords="axes fraction",
                ha='center', va='center', fontsize=font_size)

# Subset by selecting environmental variables only
df_env = df_rich_env[["Altitude", "Actual_river_slope","Elevation_mean_catch", "prec_ann_catch","temp_ann","temp_jan","temp_jul"]]

# Plot the matrix
sns.set(style='white', font_scale=1.6)
g = sns.PairGrid(df_env, aspect=1.4, diag_sharey=False)
g.map_lower(sns.regplot, lowess=True, ci=False, line_kws={'color': 'black'})
g.map_diag(sns.histplot, kde_kws={'color': 'black'})
g.map_upper(corrdot);

# %%
# Better to remove altitude, elevation of the upstream catchment and mean annual temperature from the model

y=df_rich_env["sp_rich"]
x=df_rich_env[["Actual_river_slope", "prec_ann_catch","temp_jan","temp_jul"]]

x = sm.add_constant(x) # adding a constant (Intercept)

model = sm.OLS(y, x).fit()

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sp_rich   R-squared:                       0.382
# Model:                            OLS   Adj. R-squared:                  0.381
# Method:                 Least Squares   F-statistic:                     435.4
# Date:                Sun, 20 Jul 2025   Prob (F-statistic):          2.07e-292
# Time:                        10:28:15   Log-Likelihood:                -5833.7
# No. Observations:                2822   AIC:                         1.168e+04
# Df Residuals:                    2817   BIC:                         1.171e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -7.6820      0.581    -13.217      0.000      -8.822      -6.542
# Actual_river_slope    -1.2228      0.095    -12.884      0.000      -1.409      -1.037
# prec_ann_catch         0.0004      0.000      2.317      0.021    6.19e-05       0.001
# temp_jan               0.0513      0.018      2.874      0.004       0.016       0.086
# temp_jul               0.5781      0.024     23.868      0.000       0.531       0.626
# ==============================================================================
# Omnibus:                      211.406   Durbin-Watson:                   1.156
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              336.734
# Skew:                           0.577   Prob(JB):                     7.57e-74
# Kurtosis:                       4.239   Cond. No.                     1.78e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.78e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
